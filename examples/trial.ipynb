# %%
from feature_salad import FeatureSalad
import pandas as pd

# %%
fs = FeatureSalad(
    n_numerical=5,
    n_categorical=5,
    n_numerical_int=2,
    n_categorical_int=2,
    n_samples=100,
    start_date='2023-03-01',
    end_date='2023-03-31'
)

# %%
fs.generate()

# %%
fs.X.dtypes
# Out:
# date         datetime64[s]
# computing            int64
# traning              int64
# simpler            float64
# stagnate           float64
# middle            category
# nuton              float64
# shibiao           category
# turnovers         category
# exceeded          category
# armistice         category
# dtype: object

# %%
fs.X
# Out:
#                   date  computing  traning    simpler   stagnate middle
# 0  2023-03-01 00:00:00          0        5   7.181653  41.694533     66  \
# 1  2023-03-01 07:16:21         29       13  22.406522  27.043298     47
# 2  2023-03-01 14:32:43         22        0  54.136467  68.918842     11
# 3  2023-03-01 21:49:05         18       26   1.120835  39.247406     15
# 4  2023-03-02 05:05:27         10       15  57.533967   7.513482     43
# ..                 ...        ...      ...        ...        ...    ...
# 95 2023-03-29 18:54:32         12        8   9.802658  64.437125      0
# 96 2023-03-30 02:10:54         23       26  23.303462   4.788043     39
# 97 2023-03-30 09:27:16         19       25  22.439436  28.476498     31
# 98 2023-03-30 16:43:38         29       15  35.230362  63.133332     12
# 99 2023-03-31 00:00:00          9        6  24.394945  14.848938     28
#
#         nuton shibiao turnovers  exceeded  armistice
# ...

# %%
fs.to_parquet('salad.parquet')
